# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('PDCount.csv')
# PDCount.csv is renamed csv file from https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=9810000201
# Used download option CSV 'download selected data (for database loading)'
df.to_csv('PDCount.csv', index=False)
df = pd.read_csv('PDCount.csv')
df.head(15)
# Out:
#     REF_DATE             GEO             DGUID  \
# 0       2021          Canada    2021A000011124
# 1       2021          Canada    2021A000011124
# 2       2021          Canada    2021A000011124
# 3       2021          Canada    2021A000011124
# 4       2021          Canada    2021A000011124
# 5       2021          Canada    2021A000011124
# 6       2021          Canada    2021A000011124
# 7       2021          Canada    2021A000011124
# 8       2021          Canada    2021A000011124
# 9       2021          Canada    2021A000011124
# 10      2021          Canada    2021A000011124
# 11      2021          Canada    2021A000011124
# 12      2021          Canada    2021A000011124
# 13      2021  Admirals Beach  2021A00051001186
# 14      2021  Admirals Beach  2021A00051001186
#
#                   Population and dwelling counts (13)  UOM  UOM_ID  \
# 0                                    Population, 2021  NaN       0
# 1                                    Population, 2016  NaN       0
# ...

# %%
print(df.shape)
print(df.columns)
#understanding the layout of the CSV
# Out:
# (67106, 15)
# Index(['REF_DATE', 'GEO', 'DGUID', 'Population and dwelling counts (13)',
#        'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE',
#        'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='str')

# %%
print(df.info())
#understanding the layout of the CSV
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 67106 entries, 0 to 67105
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   REF_DATE                             67106 non-null  int64
#  1   GEO                                  67106 non-null  str
#  2   DGUID                                67106 non-null  str
#  3   Population and dwelling counts (13)  67106 non-null  str
#  4   UOM                                  0 non-null      float64
#  5   UOM_ID                               67106 non-null  int64
#  6   SCALAR_FACTOR                        67106 non-null  str
#  7   SCALAR_ID                            67106 non-null  int64
#  8   VECTOR                               0 non-null      float64
#  9   COORDINATE                           67106 non-null  float64
#  10  VALUE                                65785 non-null  float64
# ...

# %%
df['SCALAR_ID']
#understanding the layout of the CSV
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 67101    0
# 67102    0
# 67103    0
# 67104    0
# 67105    0
# Name: SCALAR_ID, Length: 67106, dtype: int64

# %%
print(df.describe())
#understanding the layout of the CSV
# Out:
#        REF_DATE  UOM   UOM_ID  SCALAR_ID  VECTOR    COORDINATE         VALUE  \
# count   67106.0  0.0  67106.0    67106.0     0.0  67106.000000  6.578500e+04
# mean     2021.0  NaN      0.0        0.0     NaN   2751.271504  4.545769e+03
# std         0.0  NaN      0.0        0.0     NaN   1581.096991  2.358593e+05
# min      2021.0  NaN      0.0        0.0     NaN      1.100000 -1.000000e+02
# 25%      2021.0  NaN      0.0        0.0     NaN   1380.325000  7.300000e+00
# 50%      2021.0  NaN      0.0        0.0     NaN   2775.000000  1.570000e+02
# 75%      2021.0  NaN      0.0        0.0     NaN   4115.275000  8.100000e+02
# max      2021.0  NaN      0.0        0.0     NaN   5468.900000  3.699198e+07
#
#        TERMINATED      DECIMALS
# count         0.0  67106.000000
# mean          NaN      0.461538
# std           NaN      0.634329
# min           NaN      0.000000
# 25%           NaN      0.000000
# 50%           NaN      0.000000
# 75%           NaN      1.000000
# ...

# %%
df = df[['GEO', 'DGUID', 'Population and dwelling counts (13)', 'VALUE']]
df.head(13)
#understanding the filtered layout of the CSV
# Out:
#        GEO           DGUID                Population and dwelling counts (13)  \
# 0   Canada  2021A000011124                                   Population, 2021
# 1   Canada  2021A000011124                                   Population, 2016
# 2   Canada  2021A000011124         Population percentage change, 2016 to 2021
# 3   Canada  2021A000011124                      Total private dwellings, 2021
# 4   Canada  2021A000011124                      Total private dwellings, 2016
# 5   Canada  2021A000011124  Total private dwellings percentage change, 201...
# 6   Canada  2021A000011124  Private dwellings occupied by usual residents,...
# 7   Canada  2021A000011124  Private dwellings occupied by usual residents,...
# 8   Canada  2021A000011124  Private dwellings occupied by usual residents ...
# 9   Canada  2021A000011124               Land area in square kilometres, 2021
# 10  Canada  2021A000011124      Population density per square kilometre, 2021
# ...

# %%
df.to_csv('ProcessedPopDwelCountMNK.csv', index=False)
#Creation of the preocessed CSV
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv('ProcessedPDCount.csv', index=False)
#
# NameError: name 'df' is not defined
