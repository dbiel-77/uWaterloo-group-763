# %%
import pandas as pd
import numpy as np
df = pd.read_csv('98100002.csv')
df.head()
df.shape
df.columns
df.info()
df.describe()
df.duplicated()
df_clean = df.drop_duplicates()
df_selected = df_clean.iloc[:, [0, 1, 2, 3, 22]]
df_sorted = df_selected.sort_values(by=df_selected.columns[4], ascending=True)
df_selected.to_csv("landareabymunicipality.csv", index=False)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5468 entries, 0 to 5467
# Data columns (total 30 columns):
#  #   Column                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                  --------------  -----
#  0   REF_DATE                                                                                                                5468 non-null   int64
#  1   GEO                                                                                                                     5468 non-null   str
#  2   DGUID                                                                                                                   5468 non-null   str
#  3   Coordinate                                                                                                              5468 non-null   int64
# ...
